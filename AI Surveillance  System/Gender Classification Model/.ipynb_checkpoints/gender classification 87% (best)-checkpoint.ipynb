# %%
import os
import random
import shutil
import glob as gb
from tqdm import tqdm
from collections import Counter

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
import torch

from tensorflow.keras.preprocessing.image import load_img,img_to_array 
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, AveragePooling2D,Flatten, Dropout, Add
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input 
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.models import Model

from keras import Model
from keras.layers import Input

from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix

from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPooling2D
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow.keras.regularizers import l2

# %%
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import (
    Input, Dense, Dropout, BatchNormalization, Activation,
    Concatenate, RandomFlip, RandomRotation, RandomZoom,
    RandomTranslation, GlobalAveragePooling2D
)
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import tensorflow as tf
import numpy as np
from tensorflow.keras.regularizers import l1, l2

# %%
def visualize_random_images(male_folder, female_folder, num_images=5):
    male_images = os.listdir(male_folder)
    female_images = os.listdir(female_folder)

    fig, axes = plt.subplots(2, num_images, figsize=(15, 7))
    plt.subplots_adjust(wspace=0.3, hspace=0.3)

    for i in range(num_images):
        male_image_path = os.path.join(male_folder, random.choice(male_images))
        female_image_path = os.path.join(female_folder, random.choice(female_images))

        male_img = plt.imread(male_image_path)
        female_img = plt.imread(female_image_path)

        axes[0, i].imshow(male_img)
        axes[0, i].axis('off')
        axes[0, i].set_title('Male')

        axes[1, i].imshow(female_img)
        axes[1, i].axis('off')
        axes[1, i].set_title('Female')

    plt.show()

# %%
male_folder = (r"C:\SIH Project\Dataset\archive (2)\CCTV Gender Classifier Dataset\MALE")
female_folder = (r"C:\SIH Project\Dataset\archive (2)\CCTV Gender Classifier Dataset\FEMALE")
visualize_random_images(male_folder, female_folder)

# %%
num_male_images = len(os.listdir(male_folder))
num_female_images = len(os.listdir(female_folder))

print(f"Total number of male images: {num_male_images}")
print(f"Total number of female images: {num_female_images}")
# Out:
# Total number of male images: 9626
# Total number of female images: 9759

# %%
# Create bar plot
categories = ['Male', 'Female']
num_images = [num_male_images, num_female_images]

plt.bar(categories, num_images, color=['blue', 'pink'])
plt.xlabel('Category')
plt.ylabel('Number of Images')
plt.title('Number of Images in Each Category')
plt.show()

# %%
DataPath = (r"C:\SIH Project\Dataset\archive (2)\CCTV Gender Classifier Dataset")

labels2int={"MALE":0,"FEMALE":1}
int2labels={0:"MALE",1:"FEMALE"}

Data = []
Classes = []

# Iterate through each folder in DataPath
for folder in os.listdir(DataPath):
    print(folder)
    
    # Construct the full path to the folder
    folder_path = os.path.join(DataPath, folder)
    
    # Get a list of all files in the folder
    files = os.listdir(folder_path)
    
    print(f"Data found {len(files)} in {folder}")
    
    # Iterate through each file in the folder
    for file in files:
        # Construct the full path to the file
        file_path = os.path.join(folder_path, file)
        
        # Load the image, resize it, and convert it to an array
        img = load_img(file_path, target_size=(200, 100))
        img_array = img_to_array(img)
        
        # Preprocess the image array
        img_array = preprocess_input(img_array)
        
        # Append the preprocessed image array to the Data list
        Data.append(img_array)
        
        # Append the label to the Classes list based on the folder name
        Classes.append(labels2int[folder])
# Out:
# FEMALE
# Data found 9759 in FEMALE
# MALE
# Data found 9626 in MALE

# %%
print("Length of Classes before binarization:", len(Classes))
# Out:
# Length of Classes before binarization: 19385

# %%
lb = LabelBinarizer()
Classes = lb.fit_transform(Classes)
Classes = to_categorical(Classes)
print("Shape of Classes after binarization and conversion:", Classes.shape)
# Out:
# Shape of Classes after binarization and conversion: (19385, 2)

# %%
Data = np.array(Data,dtype = "float32")
Classes = np.array(Classes)
trainx,testx,trainy,testy = train_test_split(Data,Classes,test_size=0.20,stratify=Classes,
                                             random_state=42,shuffle=True)
print("Shape of training data (trainx):", trainx.shape)
print("Shape of testing data (testx):", testx.shape)
print("Shape of training labels (trainy):", trainy.shape)
print("Shape of testing labels (testy):", testy.shape)
# Out:
# Shape of training data (trainx): (15508, 200, 100, 3)
# Shape of testing data (testx): (3877, 200, 100, 3)
# Shape of training labels (trainy): (15508, 2)
# Shape of testing labels (testy): (3877, 2)

# %%
Data = np.array(Data,dtype = "float32")
Classes = np.array(Classes)
# Split data into training and testing sets (80% train, 20% test)
Data_train, Data_test, Classes_train, Classes_test = train_test_split(Data, Classes, test_size=0.2, random_state=42)

# Split training data into training and validation sets (80% train, 20% validation)
Data_train, Data_val, Classes_train, Classes_val = train_test_split(Data_train, Classes_train, test_size=0.2, random_state=42)

print("Shape of training data (Data_train):", Data_train.shape)
print("Shape of Validation data (Data_val):", Data_val.shape)
print("Shape of testing data (Data_test):", Data_test.shape)
print('=============================================================')
print("Shape of training labels (Classes_train):", Classes_train.shape)
print("Shape of Validation labels (Classes_test):", Classes_val.shape)
print("Shape of testing labels (Classes_test):", Classes_test.shape)
# Out:
# Shape of training data (Data_train): (12406, 200, 100, 3)
# Shape of Validation data (Data_val): (3102, 200, 100, 3)
# Shape of testing data (Data_test): (3877, 200, 100, 3)
# =============================================================
# Shape of training labels (Classes_train): (12406, 2)
# Shape of Validation labels (Classes_test): (3102, 2)
# Shape of testing labels (Classes_test): (3877, 2)

# %%
print("Training data shape:", Data_train.shape)
print("Training labels shape:", Classes_train.shape)
print("Memory usage of training data (GB):", Data_train.nbytes / 1e9)
# Out:
# Training data shape: (12406, 200, 100, 3)
# Training labels shape: (12406, 2)
# Memory usage of training data (GB): 2.97744

# %%
import tensorflow as tf

physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    try:
        # Configure GPU to use mixed precision
        tf.keras.mixed_precision.set_global_policy('mixed_float16')
        
        # Configure memory growth
        for device in physical_devices:
            tf.config.experimental.set_memory_growth(device, True)
            
        # Set memory limit to 5GB (leaving some buffer)
        tf.config.set_logical_device_configuration(
            physical_devices[0],
            [tf.config.LogicalDeviceConfiguration(memory_limit=5120)])
            
    except RuntimeError as e:
        print(e)
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA GeForce RTX 3050 6GB Laptop GPU, compute capability 8.6

# %%
def resnet50_modelarch():
    lr = 5e-5  # Reduced learning rate
    epochs = 50
    
    # Data augmentation layer
    data_augmentation = Sequential([
        RandomFlip("horizontal"),
        RandomRotation(0.1),
        RandomZoom(0.1),
    ], name="data_augmentation")
    
    # Input layer
    inputs = Input(shape=(200,100,3))
    x = data_augmentation(inputs)
    
    # Base model
    basemodel = ResNet50(include_top=False, input_tensor=x, weights='imagenet')
    
    # Freeze more layers initially
    for layer in basemodel.layers[:-20]:  # Freeze more layers compared to original
        layer.trainable = False
    
    headmodel = basemodel.output
    headmodel = GlobalAveragePooling2D()(headmodel)  # Changed to Global pooling
    
    # Reduced complexity in dense layers
    headmodel = Dense(512, activation="relu", 
                     kernel_regularizer=l2(0.01),
                     activity_regularizer=l1(0.01))(headmodel)
    headmodel = BatchNormalization()(headmodel)
    headmodel = Dropout(0.5)(headmodel)  # Increased dropout
    
    headmodel = Dense(256, activation="relu",
                     kernel_regularizer=l2(0.01))(headmodel)
    headmodel = BatchNormalization()(headmodel)
    headmodel = Dropout(0.5)(headmodel)
    
    # Final classification layer
    headmodel = Dense(2, activation='softmax')(headmodel)
    
    model = Model(inputs=inputs, outputs=headmodel)
    
    # Improved learning rate schedule
    initial_learning_rate = lr
    decay_steps = 2000  # Increased decay steps
    decay_rate = 0.95   # Gentler decay
    lr_schedule = ExponentialDecay(
        initial_learning_rate,
        decay_steps=decay_steps,
        decay_rate=decay_rate,
        staircase=True)
    
    # Using standard Adam optimizer with good defaults
    opt = Adam(
        learning_rate=lr_schedule,
        beta_1=0.9,
        beta_2=0.999,
        epsilon=1e-07,
        amsgrad=True  # Enable AMSGrad variant
    )
    
    model.compile(
        loss="binary_crossentropy", 
        optimizer=opt,
        metrics=["accuracy"]
    )
    
    # Multiple callbacks for better training control
    callbacks = [
        EarlyStopping(
            monitor='val_loss',
            patience=15,  # Increased patience
            restore_best_weights=True,
            min_delta=0.001  # Minimum change to qualify as an improvement
        ),
        ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=5,
            min_lr=1e-6,
            verbose=1
        ),
        ModelCheckpoint(
            'best_model.h5',
            monitor='val_loss',
            save_best_only=True,
            verbose=1
        )
    ]
    
    return model, callbacks, epochs

# %%
model,callbacks,Epochs = resnet50_modelarch()
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 200, 100, 3) 0
# __________________________________________________________________________________________________
# data_augmentation (Sequential)  (None, 200, 100, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 206, 106, 3)  0           data_augmentation[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 100, 50, 64)  9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 100, 50, 64)  256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 100, 50, 64)  0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 102, 52, 64)  0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 50, 25, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 50, 25, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 50, 25, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 50, 25, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 50, 25, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 50, 25, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 50, 25, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 50, 25, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 50, 25, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 50, 25, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 50, 25, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 50, 25, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 50, 25, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 50, 25, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 50, 25, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 50, 25, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 50, 25, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 50, 25, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 50, 25, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 50, 25, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 50, 25, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 50, 25, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 50, 25, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 50, 25, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 50, 25, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 50, 25, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 50, 25, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 50, 25, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 50, 25, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 50, 25, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 50, 25, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 50, 25, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 50, 25, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 25, 13, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 25, 13, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 25, 13, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 25, 13, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 25, 13, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 25, 13, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 25, 13, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 25, 13, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 25, 13, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 25, 13, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 25, 13, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 25, 13, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 25, 13, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 25, 13, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 25, 13, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 25, 13, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 25, 13, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 25, 13, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 25, 13, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 25, 13, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 25, 13, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 25, 13, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 25, 13, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 25, 13, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 25, 13, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 25, 13, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 25, 13, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 25, 13, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 25, 13, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 25, 13, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 25, 13, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 25, 13, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 25, 13, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 25, 13, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 25, 13, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 25, 13, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 25, 13, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 25, 13, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 25, 13, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 25, 13, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 25, 13, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 25, 13, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 13, 7, 256)   131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 13, 7, 256)   1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 13, 7, 256)   0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 13, 7, 256)   590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 13, 7, 256)   1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 13, 7, 256)   0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 13, 7, 1024)  525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 13, 7, 1024)  263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 13, 7, 1024)  4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 13, 7, 1024)  4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 13, 7, 1024)  0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 13, 7, 1024)  0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 13, 7, 256)   262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 13, 7, 256)   1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 13, 7, 256)   0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 13, 7, 256)   590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 13, 7, 256)   1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 13, 7, 256)   0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 13, 7, 1024)  263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 13, 7, 1024)  4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 13, 7, 1024)  0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 13, 7, 1024)  0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 13, 7, 256)   262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 13, 7, 256)   1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 13, 7, 256)   0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 13, 7, 256)   590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 13, 7, 256)   1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 13, 7, 256)   0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 13, 7, 1024)  263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 13, 7, 1024)  4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 13, 7, 1024)  0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 13, 7, 1024)  0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 13, 7, 256)   262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 13, 7, 256)   1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 13, 7, 256)   0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 13, 7, 256)   590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 13, 7, 256)   1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 13, 7, 256)   0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 13, 7, 1024)  263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 13, 7, 1024)  4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 13, 7, 1024)  0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 13, 7, 1024)  0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 13, 7, 256)   262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 13, 7, 256)   1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 13, 7, 256)   0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 13, 7, 256)   590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 13, 7, 256)   1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 13, 7, 256)   0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 13, 7, 1024)  263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 13, 7, 1024)  4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 13, 7, 1024)  0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 13, 7, 1024)  0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 13, 7, 256)   262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 13, 7, 256)   1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 13, 7, 256)   0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 13, 7, 256)   590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 13, 7, 256)   1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 13, 7, 256)   0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 13, 7, 1024)  263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 13, 7, 1024)  4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 13, 7, 1024)  0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 13, 7, 1024)  0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 4, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 4, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 4, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 4, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 4, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 4, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 4, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 4, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 7, 4, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 7, 4, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 7, 4, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 7, 4, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 4, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 4, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 4, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 4, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 4, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 4, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 4, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 7, 4, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 7, 4, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 7, 4, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 4, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 4, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 4, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 4, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 4, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 4, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 4, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 7, 4, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 7, 4, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 7, 4, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 2048)         0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 512)          1049088     global_average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 512)          2048        dense_3[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 512)          0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 256)          131328      dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 256)          1024        dense_4[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 256)          0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 2)            514         dropout_3[0][0]
# ==================================================================================================
# Total params: 24,771,714
# Trainable params: 10,113,794
# Non-trainable params: 14,657,920
# __________________________________________________________________________________________________

# %%
history = model.fit(
    Data_train, 
    Classes_train,
    batch_size=16,
    validation_data=(Data_val, Classes_val),
    epochs=50,
    callbacks=callbacks,  # Use the new callbacks list
    workers=4,
    max_queue_size=10,
    use_multiprocessing=True
)
# Out:
# Epoch 1/50
# 776/776 [==============================] - 53s 45ms/step - loss: 11.9920 - accuracy: 0.6108 - val_loss: 10.9135 - val_accuracy: 0.7147
#
# Epoch 00001: val_loss improved from inf to 10.91347, saving model to best_model.h5
# C:\Users\ybadr\anaconda3\Anaconda\envs\Softcomputing\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 2/50
# 776/776 [==============================] - 33s 43ms/step - loss: 10.3873 - accuracy: 0.6757 - val_loss: 9.6528 - val_accuracy: 0.7592
#
# Epoch 00002: val_loss improved from 10.91347 to 9.65283, saving model to best_model.h5
# Epoch 3/50
# 776/776 [==============================] - 33s 43ms/step - loss: 9.2493 - accuracy: 0.7119 - val_loss: 8.6590 - val_accuracy: 0.7821
#
# Epoch 00003: val_loss improved from 9.65283 to 8.65903, saving model to best_model.h5
# Epoch 4/50
# 776/776 [==============================] - 33s 42ms/step - loss: 8.3341 - accuracy: 0.7323 - val_loss: 7.8765 - val_accuracy: 0.7843
#
# Epoch 00004: val_loss improved from 8.65903 to 7.87646, saving model to best_model.h5
# Epoch 5/50
# 776/776 [==============================] - 38s 49ms/step - loss: 7.5611 - accuracy: 0.7527 - val_loss: 7.1478 - val_accuracy: 0.7966
#
# Epoch 00005: val_loss improved from 7.87646 to 7.14777, saving model to best_model.h5
# Epoch 6/50
# 776/776 [==============================] - 42s 54ms/step - loss: 6.9111 - accuracy: 0.7627 - val_loss: 6.5301 - val_accuracy: 0.8233
#
# Epoch 00006: val_loss improved from 7.14777 to 6.53012, saving model to best_model.h5
# Epoch 7/50
# 776/776 [==============================] - 41s 53ms/step - loss: 6.3538 - accuracy: 0.7760 - val_loss: 6.0204 - val_accuracy: 0.8362
#
# Epoch 00007: val_loss improved from 6.53012 to 6.02037, saving model to best_model.h5
# Epoch 8/50
# 776/776 [==============================] - 34s 44ms/step - loss: 5.8614 - accuracy: 0.7866 - val_loss: 5.5849 - val_accuracy: 0.8391
#
# Epoch 00008: val_loss improved from 6.02037 to 5.58486, saving model to best_model.h5
# Epoch 9/50
# 776/776 [==============================] - 32s 41ms/step - loss: 5.4375 - accuracy: 0.7948 - val_loss: 5.1794 - val_accuracy: 0.8475
#
# Epoch 00009: val_loss improved from 5.58486 to 5.17945, saving model to best_model.h5
# Epoch 10/50
# 776/776 [==============================] - 32s 42ms/step - loss: 5.0757 - accuracy: 0.7968 - val_loss: 4.8667 - val_accuracy: 0.8366
#
# Epoch 00010: val_loss improved from 5.17945 to 4.86669, saving model to best_model.h5
# Epoch 11/50
# 776/776 [==============================] - 33s 42ms/step - loss: 4.7370 - accuracy: 0.8086 - val_loss: 4.5842 - val_accuracy: 0.8262
#
# Epoch 00011: val_loss improved from 4.86669 to 4.58416, saving model to best_model.h5
# Epoch 12/50
# 776/776 [==============================] - 32s 42ms/step - loss: 4.4375 - accuracy: 0.8216 - val_loss: 4.2774 - val_accuracy: 0.8504
#
# Epoch 00012: val_loss improved from 4.58416 to 4.27743, saving model to best_model.h5
# Epoch 13/50
# 776/776 [==============================] - 33s 42ms/step - loss: 4.1774 - accuracy: 0.8299 - val_loss: 4.0312 - val_accuracy: 0.8543
#
# Epoch 00013: val_loss improved from 4.27743 to 4.03118, saving model to best_model.h5
# Epoch 14/50
# 776/776 [==============================] - 32s 42ms/step - loss: 3.9388 - accuracy: 0.8293 - val_loss: 3.8043 - val_accuracy: 0.8652
#
# Epoch 00014: val_loss improved from 4.03118 to 3.80433, saving model to best_model.h5
# Epoch 15/50
# 776/776 [==============================] - 32s 42ms/step - loss: 3.7248 - accuracy: 0.8324 - val_loss: 3.6180 - val_accuracy: 0.8536
#
# Epoch 00015: val_loss improved from 3.80433 to 3.61797, saving model to best_model.h5
# Epoch 16/50
# 776/776 [==============================] - 32s 41ms/step - loss: 3.5287 - accuracy: 0.8410 - val_loss: 3.4344 - val_accuracy: 0.8656
#
# Epoch 00016: val_loss improved from 3.61797 to 3.43438, saving model to best_model.h5
# Epoch 17/50
# 776/776 [==============================] - 32s 42ms/step - loss: 3.3451 - accuracy: 0.8450 - val_loss: 3.3243 - val_accuracy: 0.8514
#
# Epoch 00017: val_loss improved from 3.43438 to 3.32434, saving model to best_model.h5
# Epoch 18/50
# 776/776 [==============================] - 32s 42ms/step - loss: 3.1906 - accuracy: 0.8477 - val_loss: 3.1631 - val_accuracy: 0.8501
#
# Epoch 00018: val_loss improved from 3.32434 to 3.16309, saving model to best_model.h5
# Epoch 19/50
# 776/776 [==============================] - 32s 42ms/step - loss: 3.0296 - accuracy: 0.8602 - val_loss: 2.9769 - val_accuracy: 0.8649
#
# Epoch 00019: val_loss improved from 3.16309 to 2.97691, saving model to best_model.h5
# Epoch 20/50
# 776/776 [==============================] - 33s 43ms/step - loss: 2.8881 - accuracy: 0.8626 - val_loss: 2.8838 - val_accuracy: 0.8623
#
# Epoch 00020: val_loss improved from 2.97691 to 2.88383, saving model to best_model.h5
# Epoch 21/50
# 776/776 [==============================] - 32s 42ms/step - loss: 2.7710 - accuracy: 0.8619 - val_loss: 2.7881 - val_accuracy: 0.8675
#
# Epoch 00021: val_loss improved from 2.88383 to 2.78813, saving model to best_model.h5
# Epoch 22/50
# 776/776 [==============================] - 32s 42ms/step - loss: 2.6533 - accuracy: 0.8701 - val_loss: 2.6305 - val_accuracy: 0.8781
#
# Epoch 00022: val_loss improved from 2.78813 to 2.63053, saving model to best_model.h5
# Epoch 23/50
# 776/776 [==============================] - 32s 42ms/step - loss: 2.5386 - accuracy: 0.8746 - val_loss: 2.5313 - val_accuracy: 0.8669
#
# Epoch 00023: val_loss improved from 2.63053 to 2.53132, saving model to best_model.h5
# Epoch 24/50
# 776/776 [==============================] - 32s 42ms/step - loss: 2.4447 - accuracy: 0.8751 - val_loss: 2.4443 - val_accuracy: 0.8717
#
# Epoch 00024: val_loss improved from 2.53132 to 2.44429, saving model to best_model.h5
# Epoch 25/50
# 776/776 [==============================] - 32s 42ms/step - loss: 2.3533 - accuracy: 0.8776 - val_loss: 2.4127 - val_accuracy: 0.8527
#
# Epoch 00025: val_loss improved from 2.44429 to 2.41272, saving model to best_model.h5
# Epoch 26/50
# 776/776 [==============================] - 32s 42ms/step - loss: 2.2567 - accuracy: 0.8836 - val_loss: 2.3096 - val_accuracy: 0.8694
#
# Epoch 00026: val_loss improved from 2.41272 to 2.30956, saving model to best_model.h5
# Epoch 27/50
# 776/776 [==============================] - 32s 42ms/step - loss: 2.1823 - accuracy: 0.8844 - val_loss: 2.2073 - val_accuracy: 0.8740
#
# Epoch 00027: val_loss improved from 2.30956 to 2.20728, saving model to best_model.h5
# Epoch 28/50
# 776/776 [==============================] - 33s 42ms/step - loss: 2.1099 - accuracy: 0.8875 - val_loss: 2.1444 - val_accuracy: 0.8736
#
# Epoch 00028: val_loss improved from 2.20728 to 2.14440, saving model to best_model.h5
# Epoch 29/50
# 776/776 [==============================] - 32s 41ms/step - loss: 2.0302 - accuracy: 0.8920 - val_loss: 2.0701 - val_accuracy: 0.8801
#
# Epoch 00029: val_loss improved from 2.14440 to 2.07012, saving model to best_model.h5
# Epoch 30/50
# 776/776 [==============================] - 32s 41ms/step - loss: 1.9688 - accuracy: 0.8951 - val_loss: 2.0282 - val_accuracy: 0.8762
#
# Epoch 00030: val_loss improved from 2.07012 to 2.02821, saving model to best_model.h5
# Epoch 31/50
# 776/776 [==============================] - 32s 41ms/step - loss: 1.8908 - accuracy: 0.9025 - val_loss: 1.9507 - val_accuracy: 0.8762
#
# Epoch 00031: val_loss improved from 2.02821 to 1.95073, saving model to best_model.h5
# Epoch 32/50
# 776/776 [==============================] - 32s 42ms/step - loss: 1.8494 - accuracy: 0.8993 - val_loss: 1.9008 - val_accuracy: 0.8781
#
# Epoch 00032: val_loss improved from 1.95073 to 1.90077, saving model to best_model.h5
# Epoch 33/50
# 776/776 [==============================] - 32s 42ms/step - loss: 1.7824 - accuracy: 0.9049 - val_loss: 1.8725 - val_accuracy: 0.8781
#
# Epoch 00033: val_loss improved from 1.90077 to 1.87247, saving model to best_model.h5
# Epoch 34/50
# 776/776 [==============================] - 32s 41ms/step - loss: 1.7366 - accuracy: 0.9048 - val_loss: 1.8244 - val_accuracy: 0.8736
#
# Epoch 00034: val_loss improved from 1.87247 to 1.82443, saving model to best_model.h5
# Epoch 35/50
# 776/776 [==============================] - 32s 42ms/step - loss: 1.6881 - accuracy: 0.9068 - val_loss: 1.8082 - val_accuracy: 0.8749
#
# Epoch 00035: val_loss improved from 1.82443 to 1.80820, saving model to best_model.h5
# Epoch 36/50
# 776/776 [==============================] - 32s 42ms/step - loss: 1.6424 - accuracy: 0.9052 - val_loss: 1.7479 - val_accuracy: 0.8685
#
# Epoch 00036: val_loss improved from 1.80820 to 1.74786, saving model to best_model.h5
# Epoch 37/50
# 776/776 [==============================] - 32s 42ms/step - loss: 1.5994 - accuracy: 0.9106 - val_loss: 1.6964 - val_accuracy: 0.8785
#
# Epoch 00037: val_loss improved from 1.74786 to 1.69638, saving model to best_model.h5
# Epoch 38/50
# 776/776 [==============================] - 33s 43ms/step - loss: 1.5625 - accuracy: 0.9146 - val_loss: 1.6653 - val_accuracy: 0.8675
#
# Epoch 00038: val_loss improved from 1.69638 to 1.66526, saving model to best_model.h5
# Epoch 39/50
# 776/776 [==============================] - 32s 41ms/step - loss: 1.5224 - accuracy: 0.9111 - val_loss: 1.6129 - val_accuracy: 0.8694
#
# Epoch 00039: val_loss improved from 1.66526 to 1.61293, saving model to best_model.h5
# Epoch 40/50
# 776/776 [==============================] - 32s 41ms/step - loss: 1.4713 - accuracy: 0.9171 - val_loss: 1.5985 - val_accuracy: 0.8794
#
# Epoch 00040: val_loss improved from 1.61293 to 1.59846, saving model to best_model.h5
# Epoch 41/50
# 776/776 [==============================] - 32s 41ms/step - loss: 1.4374 - accuracy: 0.9212 - val_loss: 1.5575 - val_accuracy: 0.8727
#
# Epoch 00041: val_loss improved from 1.59846 to 1.55748, saving model to best_model.h5
# Epoch 42/50
# 776/776 [==============================] - 32s 42ms/step - loss: 1.3953 - accuracy: 0.9229 - val_loss: 1.5315 - val_accuracy: 0.8727
#
# Epoch 00042: val_loss improved from 1.55748 to 1.53146, saving model to best_model.h5
# Epoch 43/50
# 776/776 [==============================] - 33s 42ms/step - loss: 1.3728 - accuracy: 0.9223 - val_loss: 1.5083 - val_accuracy: 0.8733
#
# Epoch 00043: val_loss improved from 1.53146 to 1.50835, saving model to best_model.h5
# Epoch 44/50
# 776/776 [==============================] - 32s 42ms/step - loss: 1.3333 - accuracy: 0.9262 - val_loss: 1.5036 - val_accuracy: 0.8759
#
# Epoch 00044: val_loss improved from 1.50835 to 1.50362, saving model to best_model.h5
# Epoch 45/50
# 776/776 [==============================] - 33s 42ms/step - loss: 1.3075 - accuracy: 0.9258 - val_loss: 1.4593 - val_accuracy: 0.8756
#
# Epoch 00045: val_loss improved from 1.50362 to 1.45928, saving model to best_model.h5
# Epoch 46/50
# 776/776 [==============================] - 32s 41ms/step - loss: 1.2767 - accuracy: 0.9324 - val_loss: 1.4469 - val_accuracy: 0.8698
#
# Epoch 00046: val_loss improved from 1.45928 to 1.44689, saving model to best_model.h5
# Epoch 47/50
# 776/776 [==============================] - 33s 42ms/step - loss: 1.2505 - accuracy: 0.9299 - val_loss: 1.4557 - val_accuracy: 0.8688
#
# Epoch 00047: val_loss did not improve from 1.44689
# Epoch 48/50
# 776/776 [==============================] - 34s 43ms/step - loss: 1.2287 - accuracy: 0.9302 - val_loss: 1.4045 - val_accuracy: 0.8772
#
# Epoch 00048: val_loss improved from 1.44689 to 1.40455, saving model to best_model.h5
# Epoch 49/50
# 776/776 [==============================] - 33s 42ms/step - loss: 1.2071 - accuracy: 0.9300 - val_loss: 1.3813 - val_accuracy: 0.8772
#
# Epoch 00049: val_loss improved from 1.40455 to 1.38126, saving model to best_model.h5
# Epoch 50/50
# 776/776 [==============================] - 32s 41ms/step - loss: 1.1837 - accuracy: 0.9298 - val_loss: 1.3813 - val_accuracy: 0.8701
#
# Epoch 00050: val_loss did not improve from 1.38126

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('acc')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validate'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validate'], loc='upper left')
plt.show()

# %%
scores = model.evaluate(Data_test,Classes_test, verbose=1)
print("ResNet50 Score:",scores[1])
# Out:
# 122/122 [==============================] - 4s 30ms/step - loss: 1.4049 - accuracy: 0.8703
# ResNet50 Score: 0.8702605366706848

# %%
predIdxs = model.predict(Data_test,batch_size=8) 
predIdxs=np.argmax(predIdxs,axis=1)

# %%
from sklearn.metrics import classification_report,confusion_matrix
testy_res = Classes_test.argmax(axis=1)
CR = classification_report(testy_res, predIdxs)
print(CR)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.87      1921
#            1       0.86      0.89      0.87      1956
#
#     accuracy                           0.87      3877
#    macro avg       0.87      0.87      0.87      3877
# weighted avg       0.87      0.87      0.87      3877

# %%
# Get predictions for the test set
predictions = model.predict(Data_test)

# Convert predictions to class labels (0 for male, 1 for female)
predicted_labels = np.argmax(predictions, axis=1)

# Compare predicted labels with true labels
correct_predictions = np.sum(predicted_labels == np.argmax(Classes_test, axis=1))
total_samples = len(Classes_test)

# Calculate accuracy
accuracy = correct_predictions / total_samples
print("Test Accuracy:", accuracy)
# Out:
# Test Accuracy: 0.8702605107041527

# %%
class_names=['MALE','FEMALE']

# %%
import random
def plot_prediction(Data_test, Classes_test, n_images, class_names):
    """
    Test the model on random predictions and plot the results.
    
    Args:
        Data_test (numpy array): The test images data.
        Classes_test (numpy array): The true labels for the test images.
        n_images (int): Number of images to plot.
        class_names (list): List of class names.
    """
    # Get the total number of test images
    num_images = len(Data_test)
    
    # Randomly select indices for the images to plot
    random_indices = random.sample(range(num_images), n_images)
    
    # Make predictions on the selected test data
    predictions = np.argmax(model.predict(Data_test[random_indices]), axis=1)
    
    # Plot the randomly selected images along with their true labels and predictions
    plt.figure(figsize=(14, 15))
    for i, idx in enumerate(random_indices):
        plt.subplot(4, 3, i+1)
        plt.imshow(Data_test[idx])
        if predictions[i] == np.argmax(Classes_test[idx]):
            title_color = 'g'  # green color for correct predictions
        else:
            title_color = 'r'  # red color for incorrect predictions
        plt.title(class_names[np.argmax(Classes_test[idx])], color=title_color)
        plt.axis('off')
        
    plt.show()

# %%
plot_prediction(Data_test, Classes_test, n_images=6, class_names=class_names)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-123.68..151.061].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-123.68..151.061].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-123.68..151.061].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-123.68..151.061].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-123.68..151.061].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-123.68..151.061].

# %%
model.save("GenderClassification87Best.h5")
# Out:
# C:\Users\ybadr\anaconda3\Anaconda\envs\Softcomputing\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
