# %%
# %pip install pandas openpyxl googlemaps folium
# Out:
# Requirement already satisfied: pandas in c:\users\asus\yolov5_env\lib\site-packages (2.2.3)
# Requirement already satisfied: openpyxl in c:\users\asus\yolov5_env\lib\site-packages (3.1.5)
# Requirement already satisfied: googlemaps in c:\users\asus\yolov5_env\lib\site-packages (4.10.0)
# Requirement already satisfied: folium in c:\users\asus\yolov5_env\lib\site-packages (0.19.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\asus\yolov5_env\lib\site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\yolov5_env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\yolov5_env\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\yolov5_env\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: et-xmlfile in c:\users\asus\yolov5_env\lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: requests<3.0,>=2.20.0 in c:\users\asus\yolov5_env\lib\site-packages (from googlemaps) (2.32.3)
# Requirement already satisfied: branca>=0.6.0 in c:\users\asus\yolov5_env\lib\site-packages (from folium) (0.8.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\asus\yolov5_env\lib\site-packages (from folium) (3.1.4)
# Requirement already satisfied: xyzservices in c:\users\asus\yolov5_env\lib\site-packages (from folium) (2024.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\yolov5_env\lib\site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: six>=1.5 in c:\users\asus\yolov5_env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus\yolov5_env\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\yolov5_env\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\yolov5_env\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\yolov5_env\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import googlemaps
import folium
from folium.plugins import HeatMap
import time

# %%
def get_coordinates_google(area_name, api_key):
    """Get coordinates using Google Maps API"""
    try:
        gmaps = googlemaps.Client(key=api_key)
        # Add Delhi to make search more accurate
        result = gmaps.geocode(f"{area_name}, Delhi, India")
        
        if result and len(result) > 0:
            location = result[0]['geometry']['location']
            print(f"Successfully got coordinates for {area_name}")
            return location['lat'], location['lng']
        
        print(f"Could not find coordinates for {area_name}")
        return None, None
        
    except Exception as e:
        print(f"Error getting coordinates for {area_name}: {str(e)}")
        return None, None

# %%
def save_dataframe(df, filename, max_retries=3):
    """Try to save DataFrame to Excel with retry logic"""
    for attempt in range(max_retries):
        try:
            df.to_excel(filename, index=False)
            print(f"Successfully saved data to {filename}")
            return True
        except PermissionError:
            if attempt == max_retries - 1:
                print(f"\nERROR: Could not save to {filename}")
                print("Please close the Excel file if it's open and press Enter to try again,")
                print("or press Ctrl+C to exit.")
                input()
            else:
                print(f"File is locked, attempt {attempt + 1} of {max_retries}")
                time.sleep(2)
    return False

# %%
# Main execution code
def process_data(api_key):
    # Read the initial Excel file
    try:
        df = pd.read_excel('input_areas.xlsx')
        print("Successfully read the input Excel file")
        print("\nExisting columns:", df.columns.tolist())
    except FileNotFoundError:
        df = pd.DataFrame({
            'Area _Name': ['Dwarka', 'Rohini'],
            'Danger_Level': [1, 1]
        })
        df.to_excel('input_areas.xlsx', index=False)
        print("Created sample input Excel file")

    # Create new columns for coordinates if they don't exist
    if 'Latitude' not in df.columns:
        df['Latitude'] = None
    if 'Longitude' not in df.columns:
        df['Longitude'] = None

    # Get coordinates for each area
    print("\nFetching coordinates for existing areas...")
    for idx, row in df.iterrows():
        # Skip if coordinates already exist
        if pd.isna(row['Latitude']) or pd.isna(row['Longitude']):
            lat, lon = get_coordinates_google(row['Area _Name'], api_key)
            df.at[idx, 'Latitude'] = lat
            df.at[idx, 'Longitude'] = lon
            print(f"Processed: {row['Area _Name']}")
            time.sleep(0.5)  # Small delay between requests
        else:
            print(f"Skipping {row['Area _Name']}: coordinates already exist")

    # Save the updated DataFrame
    while not save_dataframe(df, 'women_safety_delhi_areas.xlsx'):
        pass
    print("\nInitial data processing complete and saved!")
    return df

# %%
def process_new_area(df, new_area, api_key):
    # Convert to lowercase for case-insensitive comparison
    existing_areas = df['Area _Name'].str.lower()
    new_area_lower = new_area.lower()
    
    if new_area_lower in existing_areas.values:
        # Update danger level for existing area
        idx = existing_areas[existing_areas == new_area_lower].index[0]
        df.at[idx, 'Danger_Level'] += 1
        print(f"Area '{new_area}' already exists. Danger level increased to {df.at[idx, 'Danger_Level']}")
    else:
        # Add new area
        lat, lon = get_coordinates_google(new_area, api_key)
        if lat and lon:
            new_row = pd.DataFrame({
                'Area _Name': [new_area],
                'Latitude': [lat],
                'Longitude': [lon],
                'Danger_Level': [1]
            })
            df = pd.concat([df, new_row], ignore_index=True)
            print(f"Added new area: {new_area}")
        else:
            print(f"Could not find coordinates for {new_area}")
    
    # Save updates
    while not save_dataframe(df, 'women_safety_delhi_areas.xlsx'):
        pass
    return generate_heatmap(df)

# %%
def generate_heatmap(df):
    """Generate and save heatmap"""
    # Initialize the map centered on Delhi
    m = folium.Map(location=[28.6139, 77.2090], zoom_start=11)
    
    # Add heatmap data
    heat_data = [[row['Latitude'], row['Longitude'], row['Danger_Level']] 
                 for idx, row in df.iterrows() 
                 if pd.notnull(row['Latitude']) and pd.notnull(row['Longitude'])]
    
    HeatMap(heat_data).add_to(m)
    
    # Save the heatmap
    m.save('heatmap.html')
    print("\nHeatmap updated and saved as 'heatmap.html'")
    return m

# Example usage:
api_key ='AIzaSyD6afYvGncWQGcdxgAcGQ4Z1g0QPVVSztU'
df = process_data(api_key)
# Out:
# Successfully read the input Excel file
#
# Existing columns: ['Area _Name', 'Danger_Level']
#
# Fetching coordinates for existing areas...
# Successfully got coordinates for Connaught Place
# Processed: Connaught Place
# Successfully got coordinates for Chandni Chowk
# Processed: Chandni Chowk
# Successfully got coordinates for Hauz Khas
# Processed: Hauz Khas
# Successfully got coordinates for Saket
# Processed: Saket
# Successfully got coordinates for Lajpat Nagar
# Processed: Lajpat Nagar
# Successfully got coordinates for Dwarka
# Processed: Dwarka
# Successfully got coordinates for Greater Kailash
# Processed: Greater Kailash
# Successfully got coordinates for Karol Bagh
# Processed: Karol Bagh
# Error getting coordinates for Rajouri Garden: HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/geocode/json?address=Rajouri+Garden%2C+Delhi%2C+India&key=AIzaSyD6afYvGncWQGcdxgAcGQ4Z1g0QPVVSztU (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
# Processed: Rajouri Garden
# Successfully got coordinates for Vasant Kunj
# Processed: Vasant Kunj
# Could not find coordinates for Rohini
# Processed: Rohini
# Successfully got coordinates for Pitampura
# Processed: Pitampura
# Successfully got coordinates for Janakpuri
# Processed: Janakpuri
# Successfully got coordinates for Laxmi Nagar
# Processed: Laxmi Nagar
# Successfully got coordinates for Nehru Place
# Processed: Nehru Place
# Successfully got coordinates for Kalkaji
# Processed: Kalkaji
# Successfully got coordinates for Sarojini Nagar
# Processed: Sarojini Nagar
# Error getting coordinates for Safdarjung Enclave: HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/geocode/json?address=Safdarjung+Enclave%2C+Delhi%2C+India&key=AIzaSyD6afYvGncWQGcdxgAcGQ4Z1g0QPVVSztU (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
# Processed: Safdarjung Enclave
# Successfully got coordinates for Malviya Nagar
# Processed: Malviya Nagar
# Error getting coordinates for Inderpuri: HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/geocode/json?address=Inderpuri%2C+Delhi%2C+India&key=AIzaSyD6afYvGncWQGcdxgAcGQ4Z1g0QPVVSztU (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
# Processed: Inderpuri
# Successfully got coordinates for Shahdara
# Processed: Shahdara
# Successfully got coordinates for Dilshad Garden
# Processed: Dilshad Garden
# Error getting coordinates for Shalimar Bagh: HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/geocode/json?address=Shalimar+Bagh%2C+Delhi%2C+India&key=AIzaSyD6afYvGncWQGcdxgAcGQ4Z1g0QPVVSztU (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
# Processed: Shalimar Bagh
# Successfully got coordinates for Punjabi Bagh
# Processed: Punjabi Bagh
# Error getting coordinates for Paschim Vihar: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Processed: Paschim Vihar
# Successfully got coordinates for Kashmere Gate
# Processed: Kashmere Gate
# Successfully got coordinates for IIT Delhi
# Processed: IIT Delhi
# Successfully got coordinates for Mayur Vihar
# Processed: Mayur Vihar
# Error getting coordinates for Preet Vihar: HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/geocode/json?address=Preet+Vihar%2C+Delhi%2C+India&key=AIzaSyD6afYvGncWQGcdxgAcGQ4Z1g0QPVVSztU (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1000)')))
# Processed: Preet Vihar
# Successfully got coordinates for Yamuna Vihar
# Processed: Yamuna Vihar
# Error getting coordinates for Okhla: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Processed: Okhla
# Error getting coordinates for Gurgaon Road: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# Processed: Gurgaon Road
# Successfully got coordinates for New Friends Colony
# Processed: New Friends Colony
# Successfully got coordinates for Jasola
# Processed: Jasola
# Successfully got coordinates for Moti Nagar
# Processed: Moti Nagar
# Successfully got coordinates for Tagore Garden
# Processed: Tagore Garden
# Successfully got coordinates for Vikaspuri
# Processed: Vikaspuri
# Could not find coordinates for Palam
# Processed: Palam
# Successfully got coordinates for Kapashera
# Processed: Kapashera
# Successfully got coordinates for Burari
# Processed: Burari
# Successfully got coordinates for Mehrauli
# Processed: Mehrauli
# Successfully got coordinates for Ghitorni
# Processed: Ghitorni
# Successfully got coordinates for Mundka
# Processed: Mundka
# Successfully got coordinates for Najafgarh
# Processed: Najafgarh
# Successfully got coordinates for Sultanpur
# Processed: Sultanpur
# Could not find coordinates for Mahipalpur
# Processed: Mahipalpur
# Successfully got coordinates for Uttam Nagar
# Processed: Uttam Nagar
# Successfully got coordinates for Vasant Vihar
# Processed: Vasant Vihar
# Successfully got coordinates for Chanakyapuri
# Processed: Chanakyapuri
# Successfully got coordinates for Model Town
# Processed: Model Town
# Successfully got coordinates for GTB Nagar
# Processed: GTB Nagar
# Successfully got coordinates for Civil Lines
# Processed: Civil Lines
# Successfully got coordinates for Rajender Nagar
# Processed: Rajender Nagar
# Successfully got coordinates for Khan Market
# Processed: Khan Market
# Successfully got coordinates for Old Rajinder Nagar
# Processed: Old Rajinder Nagar
# Successfully got coordinates for Naraina
# Processed: Naraina
# Successfully got coordinates for Munirka
# Processed: Munirka
# Successfully got coordinates for Defence Colony
# Processed: Defence Colony
# Successfully got coordinates for Anand Vihar
# Processed: Anand Vihar
# Successfully got coordinates for Ashok Vihar
# Processed: Ashok Vihar
# Successfully got coordinates for Moolchand
# Processed: Moolchand
# Successfully got coordinates for South Extension
# Processed: South Extension
# Successfully got coordinates for East of Kailash
# Processed: East of Kailash
# Could not find coordinates for Noida Border
# Processed: Noida Border
# Successfully got coordinates for Badarpur
# Processed: Badarpur
# Successfully got coordinates for Jahangirpuri
# Processed: Jahangirpuri
# Error getting coordinates for Mangolpuri: ('Connection aborted.', ConnectionAbortedError(10053, 'An established connection was aborted by the software in your host machine', None, 10053, None))
# Processed: Mangolpuri
# Error getting coordinates for Rithala: HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/geocode/json?address=Rithala%2C+Delhi%2C+India&key=AIzaSyD6afYvGncWQGcdxgAcGQ4Z1g0QPVVSztU (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000018ABCC67A40>: Failed to resolve 'maps.googleapis.com' ([Errno 11001] getaddrinfo failed)"))
# Processed: Rithala
# Error getting coordinates for Gurugram: HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/geocode/json?address=Gurugram%2C+Delhi%2C+India&key=AIzaSyD6afYvGncWQGcdxgAcGQ4Z1g0QPVVSztU (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000018ABC92EED0>: Failed to resolve 'maps.googleapis.com' ([Errno 11001] getaddrinfo failed)"))
# Processed: Gurugram
# Error getting coordinates for Bawana: HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/geocode/json?address=Bawana%2C+Delhi%2C+India&key=AIzaSyD6afYvGncWQGcdxgAcGQ4Z1g0QPVVSztU (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000018ABCC03110>: Failed to resolve 'maps.googleapis.com' ([Errno 11001] getaddrinfo failed)"))
# Processed: Bawana
# Error getting coordinates for Seelampur: HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/geocode/json?address=Seelampur%2C+Delhi%2C+India&key=AIzaSyD6afYvGncWQGcdxgAcGQ4Z1g0QPVVSztU (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000018ABCC67650>: Failed to resolve 'maps.googleapis.com' ([Errno 11001] getaddrinfo failed)"))
# Processed: Seelampur
# Error getting coordinates for Khichripur: HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/geocode/json?address=Khichripur%2C+Delhi%2C+India&key=AIzaSyD6afYvGncWQGcdxgAcGQ4Z1g0QPVVSztU (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000018ABCC657C0>: Failed to resolve 'maps.googleapis.com' ([Errno 11001] getaddrinfo failed)"))
# Processed: Khichripur
# Error getting coordinates for Patparganj: HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/geocode/json?address=Patparganj%2C+Delhi%2C+India&key=AIzaSyD6afYvGncWQGcdxgAcGQ4Z1g0QPVVSztU (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000018ABCC90500>: Failed to resolve 'maps.googleapis.com' ([Errno 11001] getaddrinfo failed)"))
# Processed: Patparganj
# Error getting coordinates for Pahar Ganj: HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/geocode/json?address=Pahar+Ganj%2C+Delhi%2C+India&key=AIzaSyD6afYvGncWQGcdxgAcGQ4Z1g0QPVVSztU (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000018ABCC90EF0>: Failed to resolve 'maps.googleapis.com' ([Errno 11001] getaddrinfo failed)"))
# Processed: Pahar Ganj
# Error getting coordinates for Nangloi: HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/geocode/json?address=Nangloi%2C+Delhi%2C+India&key=AIzaSyD6afYvGncWQGcdxgAcGQ4Z1g0QPVVSztU (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000018ABCC333B0>: Failed to resolve 'maps.googleapis.com' ([Errno 11001] getaddrinfo failed)"))
# Processed: Nangloi
# Error getting coordinates for Hari Nagar: HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/geocode/json?address=Hari+Nagar%2C+Delhi%2C+India&key=AIzaSyD6afYvGncWQGcdxgAcGQ4Z1g0QPVVSztU (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000018ABCC67710>: Failed to resolve 'maps.googleapis.com' ([Errno 11001] getaddrinfo failed)"))
# Processed: Hari Nagar
# Error getting coordinates for GT Road: HTTPSConnectionPool(host='maps.googleapis.com', port=443): Max retries exceeded with url: /maps/api/geocode/json?address=GT+Road%2C+Delhi%2C+India&key=AIzaSyD6afYvGncWQGcdxgAcGQ4Z1g0QPVVSztU (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000018ABCC65370>: Failed to resolve 'maps.googleapis.com' ([Errno 11001] getaddrinfo failed)"))
# Processed: GT Road
# Successfully got coordinates for Tilak Nagar
# Processed: Tilak Nagar
# Successfully got coordinates for Ashram
# Processed: Ashram
# Successfully got coordinates for Lado Sarai
# Processed: Lado Sarai
# Successfully got coordinates for Dhaula Kuan
# Processed: Dhaula Kuan
# Successfully got coordinates for Azadpur
# Processed: Azadpur
# Successfully got coordinates for IGI Airport
# Processed: IGI Airport
# Successfully got coordinates for Tughlakabad
# Processed: Tughlakabad
# Successfully got coordinates for Chhatarpur
# Processed: Chhatarpur
# Successfully got coordinates for Vivek Vihar
# Processed: Vivek Vihar
# Successfully got coordinates for Surajmal Vihar
# Processed: Surajmal Vihar
# Successfully got coordinates for Kalkaji Mandir
# Processed: Kalkaji Mandir
# Successfully got coordinates for Pragati Maidan
# Processed: Pragati Maidan
# Successfully got coordinates for Indraprastha
# Processed: Indraprastha
# Successfully got coordinates for Jor Bagh
# Processed: Jor Bagh
# Successfully got coordinates for RK Puram
# Processed: RK Puram
# Successfully got coordinates for Ramesh Nagar
# Processed: Ramesh Nagar
# Successfully got coordinates for Nangloi Jat
# Processed: Nangloi Jat
# Successfully got coordinates for Rajokri
# Processed: Rajokri
# Successfully got coordinates for Bijwasan
# Processed: Bijwasan
# Successfully got coordinates for Dwarka Mor
# Processed: Dwarka Mor
# Successfully got coordinates for Mohan Garden
# Processed: Mohan Garden
# Successfully got coordinates for Sadar Bazar
# Processed: Sadar Bazar
# Successfully got coordinates for Pitam Pura
# Processed: Pitam Pura
# Successfully got coordinates for Adarsh Nagar
# Processed: Adarsh Nagar
# Successfully got coordinates for Dakshinpuri
# Processed: Dakshinpuri
# Successfully got coordinates for Govindpuri
# Processed: Govindpuri
# Successfully got coordinates for Green Park
# Processed: Green Park
# Successfully got coordinates for New Area
# Processed: New Area
# Successfully got coordinates for New Area
# Processed: New Area
# Successfully got coordinates for New Area
# Processed: New Area
# Successfully got coordinates for New Area
# Processed: New Area
# Successfully got coordinates for New Area
# Processed: New Area
# Successfully saved data to women_safety_delhi_areas.xlsx
#
# Initial data processing complete and saved!

# %%
while True:
    try:
        new_area = input("\nEnter a new area name (or press Enter to skip): ")
        if new_area:
            m = process_new_area(df, new_area, api_key)
        else:
            m = generate_heatmap(df)
        break
    except Exception as e:
        print(f"\nERROR: {str(e)}")
        print("Press Enter to try again, or Ctrl+C to exit.")
        input()

print("\nProcess complete! You can view the heatmap in 'heatmap.html'")
